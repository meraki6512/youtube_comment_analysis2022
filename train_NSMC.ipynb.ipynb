# %%
import json

source_file = open('first_test.json', 'r', encoding='utf-8')

array = []

for line in source_file.readlines():
    source_data = json.loads(line)
    text = source_data.get("text")
    array.append(text)
    print(text)
# Out:
# 안녕하세요, 치엠아이 치과의사 서재원입니다🦷 살면서 해본 첫 손 연기였는데 아주 즐거웠습니다! 촬영 내내 세 분 모두 정말 열정적이셔서 숏박스가 왜 대세인지 알게 되었어요~ 앞으로 더욱 승승장구하시길 기원하겠습니다🙏🏻 그리고 TU치과와 MARTH치약 (마스치약)도 사랑해주세용~~
# 2:05
# 3:50 여기가 젤 공감... 맨날 내 입에 저거 걸어놓고 가심...
# 진짜 한석준 아나운서도 연기 대박인데 여배우분이 천의 얼굴이심 ㄷㄷㄷ
# 마지막에 입술 치는거 ㅋㅋㅋㅋㅋㅋㅋ 겁나 공감되네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 리얼감 제대로네요! 과장되지 않고! 이대로 쭈욱 흥하시면 될듯~
# 아 고증 너무 지렸어요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 마지막 입술까짘ㅋㅋㅋㅋ
# 혀대보지마세요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 공감ㅇㅈ
# 4:45 여기부터 치과갈때 마다 들었던 얘기네요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아놔 /ㅇ-
# 우리동네 치과랑 어쩜저리 똑같은지 ㅎㅎㅎ
# 아말강으로 걍 하면되는데 ㅋㅋ 무슨 하품을 많이해서 ㅋㅋㅋㅋ 티난다곸ㅋㅋㅋ
# 진심 공감대 장난아님
# 다좋은데 치의들은 하실게요~~ 라고는 잘안함.
#  그것말고는 말할게 없네요. 재밌게잘봤습니다^^
# 혀 대보지마세요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 다리꼬다가 의사쌤 오고 푼거 좀 공감
# 와…….저거수술할때 고무장갑소리 진짜똑같네…
# 입 헹굴때 마취때문에 물흘리는거 대박이노 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 개 빵터졌네
# 마취 디테일 ㅆㅅㅌㅊㅋㅋㅋㅋ
# 최근에 치과 치료 3달정도 받은 사람입니다.연기가 너무 디테일하네요ㅋㅋ
# 크록스 소리 쭈악쭈악쭈악 ㅋㅋㅋㅋㅋㅋㅋ
# 네 감사합니다 저희도 같이 촬영해서 재밌었어요
# 수고많으셨습니다~
#  @abcdefghijk  님 같이 촬영함?
# 진짜충치였어요?ㅋㅋ
# 우와ㅋㅋㅋㅋㅋ 찐 의사님 손이구너
# 손 연기 예상했습니다 선생님 ㅋㅋㅋ
# 디떼일~~~~
# 선생님 손 보니 전문가는 역시 다르네요
# ...

# %%
print(array[0])
# Out:
# 안녕하세요, 치엠아이 치과의사 서재원입니다🦷 살면서 해본 첫 손 연기였는데 아주 즐거웠습니다! 촬영 내내 세 분 모두 정말 열정적이셔서 숏박스가 왜 대세인지 알게 되었어요~ 앞으로 더욱 승승장구하시길 기원하겠습니다🙏🏻 그리고 TU치과와 MARTH치약 (마스치약)도 사랑해주세용~~

# %%
import json

source_file = open('test1_02.json', 'r', encoding='utf-8')

#array = []
dest_data = {}
dest_data['text'] = []

for line in source_file.readlines():
    source_data = json.loads(line)
    text = source_data.get("text")
    #array.append(text)
    #print(text)
    dest_data['text'].append({"text": text})
    print(dest_data)
    
    
dest_file = open('test1_02_aaa.json', 'w')
json.dump(dest_data, dest_file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [12], in <cell line: 8>()
#       6 dest_data = []
#       8 for line in source_file.readlines():
# ----> 9     source_data = json.loads(line)
#      10     text = source_data.get("text")
#      11     #array.append(text)
#      12     #print(text)
#
# File ~\anaconda3\envs\open_adv\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...

# %%
import json

source_file = open('first_test.json', 'r', encoding='utf-8')

array = []
dest_data = {}
dest_data['text'] = []

for line in source_file.readlines():
    source_data = json.loads(line)
    text = source_data.get("text")
    array.append(text)
    print(text)
# Out:
# 안녕하세요, 치엠아이 치과의사 서재원입니다🦷 살면서 해본 첫 손 연기였는데 아주 즐거웠습니다! 촬영 내내 세 분 모두 정말 열정적이셔서 숏박스가 왜 대세인지 알게 되었어요~ 앞으로 더욱 승승장구하시길 기원하겠습니다🙏🏻 그리고 TU치과와 MARTH치약 (마스치약)도 사랑해주세용~~
# 2:05
# 3:50 여기가 젤 공감... 맨날 내 입에 저거 걸어놓고 가심...
# 진짜 한석준 아나운서도 연기 대박인데 여배우분이 천의 얼굴이심 ㄷㄷㄷ
# 마지막에 입술 치는거 ㅋㅋㅋㅋㅋㅋㅋ 겁나 공감되네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 리얼감 제대로네요! 과장되지 않고! 이대로 쭈욱 흥하시면 될듯~
# 아 고증 너무 지렸어요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 마지막 입술까짘ㅋㅋㅋㅋ
# 혀대보지마세요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 공감ㅇㅈ
# 4:45 여기부터 치과갈때 마다 들었던 얘기네요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아놔 /ㅇ-
# 우리동네 치과랑 어쩜저리 똑같은지 ㅎㅎㅎ
# 아말강으로 걍 하면되는데 ㅋㅋ 무슨 하품을 많이해서 ㅋㅋㅋㅋ 티난다곸ㅋㅋㅋ
# 진심 공감대 장난아님
# 다좋은데 치의들은 하실게요~~ 라고는 잘안함.
#  그것말고는 말할게 없네요. 재밌게잘봤습니다^^
# 혀 대보지마세요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 다리꼬다가 의사쌤 오고 푼거 좀 공감
# 와…….저거수술할때 고무장갑소리 진짜똑같네…
# 입 헹굴때 마취때문에 물흘리는거 대박이노 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 개 빵터졌네
# 마취 디테일 ㅆㅅㅌㅊㅋㅋㅋㅋ
# 최근에 치과 치료 3달정도 받은 사람입니다.연기가 너무 디테일하네요ㅋㅋ
# 크록스 소리 쭈악쭈악쭈악 ㅋㅋㅋㅋㅋㅋㅋ
# 네 감사합니다 저희도 같이 촬영해서 재밌었어요
# 수고많으셨습니다~
#  @abcdefghijk  님 같이 촬영함?
# 진짜충치였어요?ㅋㅋ
# 우와ㅋㅋㅋㅋㅋ 찐 의사님 손이구너
# 손 연기 예상했습니다 선생님 ㅋㅋㅋ
# 디떼일~~~~
# 선생님 손 보니 전문가는 역시 다르네요
# ...

# %%
import json

source_file = open('test1_02.json', 'r', encoding='utf-8')

array = []

for line in source_file.readlines():
    source_data = json.loads(line)
    text = source_data.get("text")
    array.append(text)
    print(text)
    dest_data['text'].append({"text": text})
    print(dest_data)
    
dest_file = open('test1_02_aaa.json', 'w')
json.dump(dest_data, dest_file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [15], in <cell line: 7>()
#       5 array = []
#       7 for line in source_file.readlines():
# ----> 8     source_data = json.loads(line)
#       9     text = source_data.get("text")
#      10     array.append(text)
#
# File ~\anaconda3\envs\open_adv\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...

# %%
import json

source_file = open('test1_02.json', 'r', encoding='utf-8')

array = []
dest_data = {}
dest_data['text'] = []

for line in source_file.readlines():
    source_data = json.loads(line)
    text = source_data.get("text")
    array.append(text)
    print(text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [16], in <cell line: 9>()
#       7 dest_data['text'] = []
#       9 for line in source_file.readlines():
# ---> 10     source_data = json.loads(line)
#      11     text = source_data.get("text")
#      12     array.append(text)
#
# File ~\anaconda3\envs\open_adv\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...

# %%
import json

source_file = open('first_test.json', 'r', encoding='utf-8')

array = []
#dest_data = {}
#dest_data['text'] = []
dest_data = []

for line in source_file.readlines():
    source_data = json.loads(line)
    text = source_data.get("text")
    array.append(text)
    print(text)
    dest_data.append({"text": text})
    #dest_data['text'].append({"text": text})
    #print(dest_data)
    
    
dest_file = open('first_test_aad.json', 'w', encoding='utf-8-sig')
dest_file.write(json.dumps(dest_data, ensure_ascii=False))
#json.dump(dest_data, dest_file)
# Out:
# 안녕하세요, 치엠아이 치과의사 서재원입니다🦷 살면서 해본 첫 손 연기였는데 아주 즐거웠습니다! 촬영 내내 세 분 모두 정말 열정적이셔서 숏박스가 왜 대세인지 알게 되었어요~ 앞으로 더욱 승승장구하시길 기원하겠습니다🙏🏻 그리고 TU치과와 MARTH치약 (마스치약)도 사랑해주세용~~
# 2:05
# 3:50 여기가 젤 공감... 맨날 내 입에 저거 걸어놓고 가심...
# 진짜 한석준 아나운서도 연기 대박인데 여배우분이 천의 얼굴이심 ㄷㄷㄷ
# 마지막에 입술 치는거 ㅋㅋㅋㅋㅋㅋㅋ 겁나 공감되네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 리얼감 제대로네요! 과장되지 않고! 이대로 쭈욱 흥하시면 될듯~
# 아 고증 너무 지렸어요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 마지막 입술까짘ㅋㅋㅋㅋ
# 혀대보지마세요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 공감ㅇㅈ
# 4:45 여기부터 치과갈때 마다 들었던 얘기네요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아놔 /ㅇ-
# 우리동네 치과랑 어쩜저리 똑같은지 ㅎㅎㅎ
# 아말강으로 걍 하면되는데 ㅋㅋ 무슨 하품을 많이해서 ㅋㅋㅋㅋ 티난다곸ㅋㅋㅋ
# 진심 공감대 장난아님
# 다좋은데 치의들은 하실게요~~ 라고는 잘안함.
#  그것말고는 말할게 없네요. 재밌게잘봤습니다^^
# 혀 대보지마세요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 다리꼬다가 의사쌤 오고 푼거 좀 공감
# 와…….저거수술할때 고무장갑소리 진짜똑같네…
# 입 헹굴때 마취때문에 물흘리는거 대박이노 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 개 빵터졌네
# 마취 디테일 ㅆㅅㅌㅊㅋㅋㅋㅋ
# 최근에 치과 치료 3달정도 받은 사람입니다.연기가 너무 디테일하네요ㅋㅋ
# 크록스 소리 쭈악쭈악쭈악 ㅋㅋㅋㅋㅋㅋㅋ
# 네 감사합니다 저희도 같이 촬영해서 재밌었어요
# 수고많으셨습니다~
#  @abcdefghijk  님 같이 촬영함?
# 진짜충치였어요?ㅋㅋ
# 우와ㅋㅋㅋㅋㅋ 찐 의사님 손이구너
# 손 연기 예상했습니다 선생님 ㅋㅋㅋ
# 디떼일~~~~
# 선생님 손 보니 전문가는 역시 다르네요
# ...
